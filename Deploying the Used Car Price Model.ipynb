# %%
from used_car_module import *

# %%
#create an object from the 'used_car_model' class
model = used_car_model('model')

# %%
#call the 'load_and_clean_data' method
model.load_and_clean_data('C:\\Users\\feder\\Downloads\\Module\\NEW Data.csv')

# %%
#call the 'predict_output' method
model.predict_output()
# Out:
#              Brand    Price       Body  Mileage  EngineV Engine Type  \
# 0              BMW   4200.0      sedan      277      2.0      Petrol
# 1    Mercedes-Benz  13300.0      sedan      358      5.0         Gas
# 2             Audi  23000.0  crossover      240      4.2      Petrol
# 3           Toyota  18300.0  crossover      120      2.0      Petrol
# 4             Audi  14200.0      vagon      200      2.7      Diesel
# ..             ...      ...        ...      ...      ...         ...
# 145     Volkswagen   7900.0      other      168      1.9      Diesel
# 146         Toyota  28500.0  crossover       97      3.5      Petrol
# 147        Renault   6900.0        van      140      1.5      Diesel
# 148            BMW   8850.0      vagon      280      2.5      Diesel
# 149        Renault   3100.0        van      164      1.4      Petrol
#
#      log_price    Prediction
# 0     8.342840   4310.719092
# 1     9.495519   5576.392276
# 2    10.043249  10623.346668
# ...

# %%
#export to a csv file for analysis in Tableau
model.predict_output().to_csv('C:\\Users\\feder\\OneDrive\\Desktop\\Co-op prep\\Used Car Price Predictions.csv', index=False, encoding='utf-8')
